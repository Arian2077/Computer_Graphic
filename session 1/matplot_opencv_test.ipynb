# %% [markdown]
# ### Computer graphic

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3,4,5]
y = [2,4,6,8,10]
plt.plot(x,y)
plt.title("Simple Line Chart")
plt.xlabel(x)
plt.ylabel(y)
plt.grid(True)
plt.show()
